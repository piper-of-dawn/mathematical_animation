# %%
import yfinance as yf
ticker = 'NVDA'
df =yf.download(ticker, start="2020-01-01", end="2024-05-31")[['Adj Close']]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df["UNIX"] = df.index.view('int64') // 10**9
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_36072\3254839582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UNIX"] = df.index.view('int64') // 10**9

# %%
df
# Out:
#              Adj Close        UNIX
# Date
# 2020-01-02    5.973632  1577923200
# 2020-01-03    5.878019  1578009600
# 2020-01-06    5.902668  1578268800
# 2020-01-07    5.974131  1578355200
# 2020-01-08    5.985336  1578441600
# ...                ...         ...
# 2024-05-23  103.790482  1716422400
# 2024-05-24  106.460258  1716508800
# 2024-05-28  113.891647  1716854400
# 2024-05-29  114.815567  1716940800
# 2024-05-30  110.490921  1717027200
#
# [1110 rows x 2 columns]

# %%
x
# Out:
# array([1577923200, 1578009600, 1578268800, ..., 1716854400, 1716940800,
#        1717027200], dtype=int64)

# %%
x = df["UNIX"].to_numpy()
y = df["Adj Close"].to_numpy()
data = {x: y for x, y in zip(x, y)}

# %%
data
# Out:
# {1577923200: 5.973632335662842,
#  1578009600: 5.878018856048584,
#  1578268800: 5.902668476104736,
#  1578355200: 5.974131107330322,
#  1578441600: 5.9853363037109375,
#  1578528000: 6.0510711669921875,
#  1578614400: 6.083439350128174,
#  1578873600: 6.274170398712158,
#  1578960000: 6.157142639160156,
#  1579046400: 6.114563941955566,
#  1579132800: 6.198226451873779,
#  1579219200: 6.206941604614258,
#  1579564800: 6.173576831817627,
#  1579651200: 6.2276082038879395,
#  1579737600: 6.296082019805908,
#  1579824000: 6.236821174621582,
#  1580083200: 5.98085355758667,
#  1580169600: 6.1743245124816895,
#  1580256000: 6.11381721496582,
#  1580342400: 6.120540618896484,
#  1580428800: 5.886981964111328,
#  1580688000: 5.9840898513793945,
#  1580774400: 6.153407573699951,
#  1580860800: 6.24379301071167,
#  1580947200: 6.330690860748291,
#  1581033600: 6.264459133148193,
#  1581292800: 6.547815799713135,
#  1581379200: 6.670321464538574,
#  1581465600: 6.786102771759033,
# ...
